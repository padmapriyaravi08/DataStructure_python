# %%
def linear_search(arr,key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1

arr=list(map(int,input("Enter elements separated by space:").split()))
key=int(input("Enter element to search:"))

#Linear Search
position=linear_search(arr,key)
if position != -1:
    print("Linear Search:Element Found At Position",position)
else:
    print("Linear Search:Element Not Found")
# Out:
# Enter elements separated by space: 14 55 25 66
# Enter element to search: 55
# Linear Search:Element Found At Position 1

# %%
def binary_search(arr,key):
    low=0
    high=len(arr)-1

    while low <= high:
        mid=(low+high) // 2
        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid+1
        else:
            high = mid - 1
    return -1

arr=list(map(int,input("Enter elements separated by space:").split()))
key=int(input("Enter element to search:"))
    # Binary Search
arr.sort()
print("Sorted array:",arr)
position=binary_search(arr,key)

if position != -1:
    print("Binary Search:Element Found At Position",position+1)
else:
    print("Binary Search:Element Not Found")
# Out:
# Enter elements separated by space: 22 55 66 45 55
# Enter element to search: 66
# Sorted array: [22, 45, 55, 55, 66]
# Binary Search:Element Found At Position 5

# %%
def linear_search(arr,key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1
    
def binary_search(arr,key):
    low=0
    high=len(arr)-1

    while low <= high:
        mid=(low+high) // 2
        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid+1
        else:
            high = mid - 1
    return -1

arr=list(map(int,input("Enter elements separated by space:").split()))
key=int(input("Enter element to search:"))

position=linear_search(arr,key)
if position != -1:
    print("Linear Search:Element Found At Position",position)
else:
    print("Linear Search:Element Not Found")

arr.sort()
print("Sorted array:",arr)
position=binary_search(arr,key)

if position != -1:
    print("Binary Search:Element Found At Position",position+1)
else:
    print("Binary Search:Element Not Found")
# Out:
# Enter elements separated by space: 55 45 66 25 32 88 66
# Enter element to search: 66
# Linear Search:Element Found At Position 2
# Sorted array: [25, 32, 45, 55, 66, 66, 88]
# Binary Search:Element Found At Position 6
