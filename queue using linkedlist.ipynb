# %%
class Node:
    def init(self,data):
        self.data=data
        self.next=None
    
class Queue:
    def init(self):
        self.front = None
        self.rear = None

    def enqueue(self,data):
        new_node = Node(data)

        if self.rear is None:
            self.front = self.rear = new_node
        else:
            self.rear.next = new_node
            self.rear = new_node
        print("Element Inserted Successfully.")

    def dequeue(self):
        if self.front is None:
            print("Queue Underflow")
        else:
            data = self.front.data
            self.front = self.front.next

        if self.front is None:
            self.rear = None

        print("Deleted Element:",data)

    def display(self):
        if self.front is None:
            print("Queue is empty")
        else:
            current = self.front
            print("Queue Elements:",end=" ")


            while current:
                print(current.data,end=" ")
                current = current.next

            print()

    queue = Queue()

while True:
    print("\n---QUEUE MENU---")
    print("1.Enqueue")
    print("2.Dequeue")
    print("3.Display")
    print("4.Exit")

    choice = int(input("Enter your choice:"))
    if choice == 1:
        value = int(input("Enter Element:"))
        queue.enqueue(value)
    elif choice == 2:
        queue.dequeue()
    elif choice == 3:
        queue.display()
    elif choice == 4:
        break
    else:
        print("Invalid Choice")
# Out:
# ---QUEUE MENU---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 1
# Enter Element: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 59
#      57 if choice == 1:
#      58     value = int(input("Enter Element:"))
# ---> 59     queue.enqueue(value)
#      60 elif choice == 2:
#      61     queue.dequeue()
#
# Cell In[6], line 12, in Queue.enqueue(self, data)
#      11 def enqueue(self,data):
# ---> 12     new_node = Node(data)
#      14     if self.rear is None:
#      15         self.front = self.rear = new_node
#
# TypeError: Node() takes no arguments

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class Queue:
    def __init__(self):
        self.front = None
        self.rear = None

    def enqueue(self, data):
        new_node = Node(data)

        if self.rear is None:
            self.front = self.rear = new_node
        else:
            self.rear.next = new_node
            self.rear = new_node

        print("Element Inserted Successfully.")

    def dequeue(self):
        if self.front is None:
            print("Queue Underflow")
            return

        data = self.front.data
        self.front = self.front.next

        if self.front is None:
            self.rear = None

        print("Deleted Element:", data)

    def display(self):
        if self.front is None:
            print("Queue is empty")
            return

        current = self.front
        print("Queue Elements:", end=" ")

        while current:
            print(current.data, end=" ")
            current = current.next

        print()


queue = Queue()

while True:
    print("\n--- QUEUE MENU ---")
    print("1. Enqueue")
    print("2. Dequeue")
    print("3. Display")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        value = int(input("Enter Element: "))
        queue.enqueue(value)

    elif choice == 2:
        queue.dequeue()

    elif choice == 3:
        queue.display()

    elif choice == 4:
        print("Exiting...")
        break

    else:
        print("Invalid Choice")
# Out:
# --- QUEUE MENU ---
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Exit
# Enter your choice:  1
# Enter Element:  10
# Element Inserted Successfully.
#
# --- QUEUE MENU ---
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Exit
# Enter your choice:  1
# Enter Element:  20
# Element Inserted Successfully.
#
# --- QUEUE MENU ---
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Exit
# Enter your choice:  1
