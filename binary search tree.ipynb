# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def inorder(root):
    if root:
        inorder(root.left)
        print(root.data,end=" ")
        inorder(root.right)

def preorder(root):
    if root:
        print(root.data,end=" ")
        preorder(root.left)
        preorder(root.right)

def postorder(root):
    if root:
        postorder(root.left)
        postorder(root.right)
        print(root.data,end=" ")

root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)

print("Inorder Traversal:")
inorder(root)

print("\nPreorder Traversal:")
preorder(root)

print("\nPostorder Travaersal:")
postorder(root)
# Out:
# Inorder Traversal:
# 4 2 5 1 3
# Preorder Traversal:
# 1 2 4 5 3
# Postorder Travaersal:
# 4 5 2 3 1

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

    def inorder(root):
        if root:
           inorder(root.left)
           print(root.data,end=" ")
           inorder(root.right)

    def preorder(root):
        if root:
             print(root.data,end=" ")
             preorder(root.left)
             preorder(root.right)

    def postorder(root):
         if root:
              postorder(root.left)
              postorder(root.right)
              print(root.data,end=" ")

root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)

print("Inorder Traversal:")
Node.inorder(root)

print("\nPreorder Traversal:")
Node.preorder(root)

print("\nPostorder Travaersal:")
Node.postorder(root)
# Out:
# Inorder Traversal:
# 4 2 5 1 3
# Preorder Traversal:
# 1 2 4 5 3
# Postorder Travaersal:
# 4 5 2 3 1

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

    def inorder(root):
        if root:
           inorder(root.left)
           print(root.data,end=" ")
           inorder(root.right)

    def preorder(root):
        if root:
             print(root.data,end=" ")
             preorder(root.left)
             preorder(root.right)

    def postorder(root):
         if root:
              postorder(root.left)
              postorder(root.right)
              print(root.data,end=" ")

root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

    def inorder(root):
        if root:
           inorder(root.left)
           print(root.data,end=" ")
           inorder(root.right)

    def preorder(root):
        if root:
             print(root.data,end=" ")
             preorder(root.left)
             preorder(root.right)

    def postorder(root):
         if root:
              postorder(root.left)
              postorder(root.right)
              print(root.data,end=" ")

root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)

print("Inorder Traversal:")
Node.inorder(root)

print("\nPreorder Traversal:")
Node.preorder(root)

print("\nPostorder Travaersal:")
Node.postorder(root)
    
     

print("Inorder Traversal:")
Node.inorder(root)

print("\nPreorder Traversal:")
Node.preorder(root)

print("\nPostorder Travaersal:")
Node.postorder(root)
# Out:
# Inorder Traversal:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 35
#      31 root.right.right=Node(7)
#      34 print("Inorder Traversal:")
# ---> 35 Node.inorder(root)
#      37 print("\nPreorder Traversal:")
#      38 Node.preorder(root)
#
# Cell In[3], line 9, in Node.inorder(root)
#       7 def inorder(root):
#       8     if root:
# ----> 9        inorder(root.left)
#      10        print(root.data,end=" ")
#      11        inorder(root.right)
#
# NameError: name 'inorder' is not defined

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

def inorder(root):
    if root:
        inorder(root.left)
        print(root.data,end=" ")
        inorder(root.right)

def preorder(root):
    if root:
        print(root.data,end=" ")
        preorder(root.left)
        preorder(root.right)

def postorder(root):
    if root:
        postorder(root.left)
        postorder(root.right)
        print(root.data,end=" ")

root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)
root.right.left=Node(6)
root.right.right=Node(7)

print("Inorder Traversal:")
inorder(root)

print("\nPreorder Traversal:")
preorder(root)

print("\nPostorder Travaersal:")
postorder(root)
# Out:
# Inorder Traversal:
# 4 2 5 1 6 3 7
# Preorder Traversal:
# 1 2 4 5 3 6 7
# Postorder Travaersal:
# 4 5 2 6 7 3 1
